# %% [markdown]
# # EW4All Multi-Hazard Risk & Readiness Index
# Real open data (JRC INFORM Risk + World Bank) for the seven EW4All pilot countries. Run each cell top to bottom (Shift+Enter).

# %%
# 1) Get the code + data (skips if already cloned)
import os
if not os.path.exists('climate-risk-early-warning'):
    # !git clone -q https://github.com/Pr0spektor/climate-risk-early-warning.git
# %cd climate-risk-early-warning
# !pip -q install -r requirements.txt

# %%
# 2) (Optional) re-fetch the latest real data live from the World Bank + INFORM APIs.
#    If the network is unavailable, the committed real snapshot in data/ is used instead.
# !python src/fetch_data.py || echo 'Live fetch skipped — using committed real snapshot in data/.'

# %%
# 3) Compute the index and generate the charts
# !python src/build_index.py

# %%
# 4) Show the results
import pandas as pd
from IPython.display import Image, display
display(pd.read_csv('results/index.csv'))
display(Image('results/index_ranking.png'))
display(Image('results/indicator_heatmap.png'))
