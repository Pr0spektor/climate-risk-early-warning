# %% [markdown]
# # EW4All Vulnerability & Readiness Index
# Real World Bank Open Data for the seven EW4All pilot countries. Run each cell top to bottom (Shift+Enter).

# %%
# 1) Get the code + data (skips if already cloned)
import os
if not os.path.exists('climate-risk-early-warning'):
    # !git clone -q https://github.com/Pr0spektor/climate-risk-early-warning.git
# %cd climate-risk-early-warning
# !pip -q install -r requirements.txt

# %%
# 2) (Optional) re-fetch the latest real data live from the World Bank API
# !python src/fetch_data.py

# %%
# 3) Compute the index and generate the charts
# !python src/build_index.py

# %%
# 4) Show the results
import pandas as pd
from IPython.display import Image, display
display(pd.read_csv('results/vulnerability_readiness_index.csv'))
display(Image('results/index_ranking.png'))
display(Image('results/indicator_heatmap.png'))
